# %%
path = '/content/Bowlers-as-Leaders-Jasprit-Bumrah-on-Why-They-Lead-Well.png'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance, ImageFilter # for mathamatical operatin on image , python imaging liabrary
from scipy.ndimage.filters import convolve
from google.colab.patches import cv2_imshow
# Out:
# <ipython-input-84-5eef6e4177cf>:5: DeprecationWarning: Please import `convolve` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import convolve

# %%
img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1080x1080>

# %%
sharpen = np.array([[1,2,1],[0,0,0],[-1,-2,-1]])
# sharpen = np.array([[3,3,3],[3,3,3],[3,3,3]])

# %%
sharpen_vertical = np.array([[-1,0,2],[-2,0,2],[-1,0,1]])

# %%
# outline
outline = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])

# %%
# kernal = sharpen_vertical
# kernal = blur1
kernal = outline
im2 = convolve(img,kernal)
im3 = np.array(np.clip(im2,0,255),dtype='uint8')

# %%
img_ew=cv2.hconcat([img,im3])
cv2_imshow(img_ew)
# Out:
# <PIL.Image.Image image mode=L size=2160x1080>

# %%
blur1 = np.ones((7,7),dtype=float)*(1/49)
